# %% [markdown]
# <a href="https://colab.research.google.com/github/EkeminiImeOtu/Projects/blob/main/API_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

# Define the headers for the API request
headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    'cache-control': 'max-age=0',
    'priority': 'u=0, i',
    'sec-ch-ua': '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'none',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36',
}

# Send the GET request to the API
response = requests.get('https://sightmap.com/app/api/v1/dzlpox6jpg4/sightmaps/13629', headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON data from the response
    data = response.json()

    # Access the 'floor_plans' and 'units' nested under 'data'
    floor_plans = data.get('data', {}).get('floor_plans', [])
    units = data.get('data', {}).get('units', [])

    # Create an empty list to store the formatted floor plan data
    floor_plan_list = []

    # Loop through each floor plan and extract relevant data
    if floor_plans:
        for plan in floor_plans:
            # Create a dictionary for each floor plan
            floor_plan_data = {
                "name": plan.get('name'),
                "buildingUniqueIdentifier": plan.get('buildingUniqueIdentifier'),
                "beds": plan.get('bedroom_count', 0),
                "baths": plan.get('bathroom_count', 0.0),
                "direction": plan.get('direction'),
                "sqft": plan.get('sqft', 0),
                "layoutImage": plan.get('image_url'),
                "isConvertable": plan.get('is_convertible', False),
                "units": []  # To hold the matching units
            }

            # Find matching units by floor_plan_id and add them to the floor plan
            for unit in units:
                if unit.get('floor_plan_id') == plan.get('id'):
                    unit_data = {
                        "unitNumber": unit.get('display_unit_number'),
                        "price": unit.get('price', 0.0),
                        "sqft": unit.get('area', 0),
                        "moveInDate": unit.get('available_on', "0001-01-01")
                    }
                    floor_plan_data['units'].append(unit_data)

            # If no units are found, we still append the floor plan with empty units
            if not floor_plan_data['units']:
                floor_plan_data['units'].append({
                    "unitNumber": None,
                    "price": 0.0,
                    "sqft": 0,
                    "moveInDate": "0001-01-01"
                })

            # Add the complete floor plan to the list
            floor_plan_list.append(floor_plan_data)

        # Convert the list of floor plans into JSON format
        json_output = json.dumps(floor_plan_list, indent=4)

        # Print the JSON data (as requested by your client)
        print(json_output)

        # Export the JSON data to a file
        json_file_path = "ae355b63-d96d-4068-b539-9b6afff879bb.json"
        with open(json_file_path, 'w') as json_file:
            json_file.write(json_output)

        print(f"Data has been exported to {json_file_path}")
    else:
        print("No floor plans found in the response.")
else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
# Out:
# [
#     {
#         "name": "B11",
#         "buildingUniqueIdentifier": null,
#         "beds": 2,
#         "baths": 2,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/92/7b/927b5fe974f80e9ef9c9b93dd9e4d26f.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "A9",
#         "buildingUniqueIdentifier": null,
#         "beds": 1,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/3c/20/3c20c3aaf9c6aaaa3567eca8c8dfa50f.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "A3",
#         "buildingUniqueIdentifier": null,
#         "beds": 1,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/8a/5f/8a5f55d02f7cd6f8289534c1d79e79de.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": "APT 309",
#                 "price": 2444,
#                 "sqft": 646,
#                 "moveInDate": "2024-10-19"
#             },
#             {
#                 "unitNumber": "APT 615",
#                 "price": 2518,
#                 "sqft": 791,
#                 "moveInDate": "2024-10-11"
#             }
#         ]
#     },
#     {
#         "name": "A5",
#         "buildingUniqueIdentifier": null,
#         "beds": 1,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/4d/7c/4d7c159d695522375d2c25de49de004a.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": "APT 222",
#                 "price": 2557,
#                 "sqft": 756,
#                 "moveInDate": "2024-10-12"
#             },
#             {
#                 "unitNumber": "APT 448",
#                 "price": 2497,
#                 "sqft": 788,
#                 "moveInDate": "2024-10-11"
#             },
#             {
#                 "unitNumber": "APT 512",
#                 "price": 2587,
#                 "sqft": 780,
#                 "moveInDate": "2024-10-11"
#             },
#             {
#                 "unitNumber": "APT 516",
#                 "price": 2425,
#                 "sqft": 794,
#                 "moveInDate": "2024-10-11"
#             },
#             {
#                 "unitNumber": "APT 608",
#                 "price": 2602,
#                 "sqft": 772,
#                 "moveInDate": "2024-10-18"
#             }
#         ]
#     },
#     {
#         "name": "S2",
#         "buildingUniqueIdentifier": null,
#         "beds": 0,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/da/8e/da8e83ed80192fdc59e94d391e833da8.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": "APT 213",
#                 "price": 2070,
#                 "sqft": 516,
#                 "moveInDate": "2024-10-11"
#             },
#             {
#                 "unitNumber": "APT 311",
#                 "price": 2071,
#                 "sqft": 513,
#                 "moveInDate": "2024-11-09"
#             }
#         ]
#     },
#     {
#         "name": "S1",
#         "buildingUniqueIdentifier": null,
#         "beds": 0,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/25/08/25080a660bccb7a9f5c09c33b386fbc0.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": "APT 255",
#                 "price": 1730,
#                 "sqft": 463,
#                 "moveInDate": "2024-10-30"
#             },
#             {
#                 "unitNumber": "APT 510",
#                 "price": 2020,
#                 "sqft": 462,
#                 "moveInDate": "2024-10-23"
#             },
#             {
#                 "unitNumber": "APT 555",
#                 "price": 1753,
#                 "sqft": 463,
#                 "moveInDate": "2024-10-11"
#             },
#             {
#                 "unitNumber": "APT 573",
#                 "price": 1762,
#                 "sqft": 460,
#                 "moveInDate": "2024-10-11"
#             },
#             {
#                 "unitNumber": "APT 749",
#                 "price": 1844,
#                 "sqft": 485,
#                 "moveInDate": "2024-10-15"
#             }
#         ]
#     },
#     {
#         "name": "A6",
#         "buildingUniqueIdentifier": null,
#         "beds": 1,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/f1/a5/f1a595b4aa9f764480921301d615dc4e.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "S6",
#         "buildingUniqueIdentifier": null,
#         "beds": 0,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/31/64/3164f8225bfd07850873b8f5a39699d7.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "S3",
#         "buildingUniqueIdentifier": null,
#         "beds": 0,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/d9/39/d9397c3000716ff37b17c1a420b097f5.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": "APT 423",
#                 "price": 1951,
#                 "sqft": 517,
#                 "moveInDate": "2024-10-11"
#             }
#         ]
#     },
#     {
#         "name": "A1",
#         "buildingUniqueIdentifier": null,
#         "beds": 1,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/25/a9/25a99bea6e20fabce909e6b71d5fd28d.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": "APT 224",
#                 "price": 2315,
#                 "sqft": 626,
#                 "moveInDate": "2024-10-11"
#             }
#         ]
#     },
#     {
#         "name": "A2",
#         "buildingUniqueIdentifier": null,
#         "beds": 1,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/f6/a8/f6a892cbede4af4371df4a1c98b49a59.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "S7",
#         "buildingUniqueIdentifier": null,
#         "beds": 0,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/11/d2/11d2d098682ac43522017cec7a2e7c3b.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": "APT 641",
#                 "price": 2330,
#                 "sqft": 628,
#                 "moveInDate": "2024-10-11"
#             },
#             {
#                 "unitNumber": "APT 741",
#                 "price": 2380,
#                 "sqft": 628,
#                 "moveInDate": "2024-10-11"
#             }
#         ]
#     },
#     {
#         "name": "B6",
#         "buildingUniqueIdentifier": null,
#         "beds": 2,
#         "baths": 2,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/4b/ed/4bed39b8dfb7fbaec4f380378b56e5cf.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": "APT 443",
#                 "price": 3406,
#                 "sqft": 1056,
#                 "moveInDate": "2024-12-12"
#             }
#         ]
#     },
#     {
#         "name": "B10",
#         "buildingUniqueIdentifier": null,
#         "beds": 2,
#         "baths": 2,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/61/06/6106fa4a11acdf19be27461f9a4ea343.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "S5",
#         "buildingUniqueIdentifier": null,
#         "beds": 0,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/0e/8f/0e8f5208c74a7bf6ad649a13daf847e7.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "S5.1",
#         "buildingUniqueIdentifier": null,
#         "beds": 0,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/84/53/8453fe2667b2b84897a32ca3660c3f06.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "S4",
#         "buildingUniqueIdentifier": null,
#         "beds": 0,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/90/fb/90fb2569134c1baf4ac3eab2679e8e2e.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "B1",
#         "buildingUniqueIdentifier": null,
#         "beds": 2,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/e1/56/e156566a285e56bdf8845514bed1c34b.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "S1.1",
#         "buildingUniqueIdentifier": null,
#         "beds": 0,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/b7/e6/b7e6395a16429edeeb6148829b6bf7b3.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "B8.1",
#         "buildingUniqueIdentifier": null,
#         "beds": 2,
#         "baths": 2,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/b0/23/b023b16bf463208cbcbe7f1c18e2f8e7.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "A5.1",
#         "buildingUniqueIdentifier": null,
#         "beds": 1,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/3d/ff/3dff6f4568ead9dcc4b1fa27e7c27dc8.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "B2",
#         "buildingUniqueIdentifier": null,
#         "beds": 2,
#         "baths": 2,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/75/71/7571359de3e7cede5666623bd20f73e4.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": "APT 483",
#                 "price": 3803,
#                 "sqft": 975,
#                 "moveInDate": "2024-10-11"
#             }
#         ]
#     },
#     {
#         "name": "B9",
#         "buildingUniqueIdentifier": null,
#         "beds": 2,
#         "baths": 2,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/07/55/0755dd13376d35177277df2950c45d07.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": "APT 604",
#                 "price": 3566,
#                 "sqft": 1215,
#                 "moveInDate": "2024-11-06"
#             }
#         ]
#     },
#     {
#         "name": "A10",
#         "buildingUniqueIdentifier": null,
#         "beds": 1,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/3e/76/3e761c9902e69c70e633bceef370f3b7.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "B3",
#         "buildingUniqueIdentifier": null,
#         "beds": 2,
#         "baths": 2,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/e2/f1/e2f1ce03ce67716f18777570f314e90c.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "C1",
#         "buildingUniqueIdentifier": null,
#         "beds": 3,
#         "baths": 2,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/ed/64/ed6405a52b4213ed2aca1b3f9a55ea64.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": "APT 525",
#                 "price": 5840,
#                 "sqft": 1299,
#                 "moveInDate": "2024-10-26"
#             }
#         ]
#     },
#     {
#         "name": "A11",
#         "buildingUniqueIdentifier": null,
#         "beds": 1,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/91/a5/91a5fac125c64a5ea028a48536b36ec0.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "B8",
#         "buildingUniqueIdentifier": null,
#         "beds": 2,
#         "baths": 2,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/55/f5/55f5a2ce0e7ffc729b2d9eaaae3b1427.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "A4.1",
#         "buildingUniqueIdentifier": null,
#         "beds": 1,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/2c/13/2c13447838d751863821d2d1b78014c5.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "B1.1",
#         "buildingUniqueIdentifier": null,
#         "beds": 2,
#         "baths": 2,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/34/d3/34d3285cb0344adc6a19d57e91ec479d.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "B5",
#         "buildingUniqueIdentifier": null,
#         "beds": 2,
#         "baths": 2,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/cc/6f/cc6f85505110657752d7b4c72c976dbf.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "A8",
#         "buildingUniqueIdentifier": null,
#         "beds": 1,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/79/0d/790d83547697f8e77fc15ef909133a73.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "A4",
#         "buildingUniqueIdentifier": null,
#         "beds": 1,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/00/3a/003a2f3b3ab29251bb6636a628506639.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "A7",
#         "buildingUniqueIdentifier": null,
#         "beds": 1,
#         "baths": 1,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/94/ff/94ffe4295c86e34bf9d360edb0b3bf1c.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "B7",
#         "buildingUniqueIdentifier": null,
#         "beds": 2,
#         "baths": 2,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/fd/bd/fdbda749e32404650f60eae76e4b36de.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "B4",
#         "buildingUniqueIdentifier": null,
#         "beds": 2,
#         "baths": 2,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/a7/a4/a7a44f3a58e147168c60ec27bba9aa83.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "C2",
#         "buildingUniqueIdentifier": null,
#         "beds": 3,
#         "baths": 2,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": "https://cdn.sightmap.com/assets/05/ev/05evenlxvqo/59/89/5989f81bf57866dca7789d287c37fb9f.jpg",
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     },
#     {
#         "name": "B2.1",
#         "buildingUniqueIdentifier": null,
#         "beds": 2,
#         "baths": 2,
#         "direction": null,
#         "sqft": 0,
#         "layoutImage": null,
#         "isConvertable": false,
#         "units": [
#             {
#                 "unitNumber": null,
#                 "price": 0.0,
#                 "sqft": 0,
#                 "moveInDate": "0001-01-01"
#             }
#         ]
#     }
# ]
# Data has been exported to ae355b63-d96d-4068-b539-9b6afff879bb.json
